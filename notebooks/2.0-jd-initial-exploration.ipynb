# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('/Users/jdickinson/Documents/PersonalRepos/cwu-fitlab/data/processed/nhanes_merged.csv')
df.head(3)
# Out:
#    SEQN  CVDEXSTS      CVDEXCMT  CVDEXCL1  CVDEXCL2  CVDEXCL3  CVDEXCL4  \
# 0   5.0       1.0  5.397605e-79       NaN       NaN       NaN       NaN
# 1   6.0       1.0  5.000000e+00       NaN       NaN       NaN       NaN
# 2   8.0       2.0  7.000000e+00       NaN       NaN       NaN       NaN
#
#    CVDEXCL5  CVDEXCL6  CVQ220A  ...  SIALANG  SIAPROXY  SIAINTRP  FIALANG  \
# 0       NaN       NaN      NaN  ...      NaN       NaN       NaN      NaN
# 1       NaN       NaN      NaN  ...      NaN       NaN       NaN      NaN
# 2       NaN       NaN      2.0  ...      NaN       NaN       NaN      NaN
#
#    FIAPROXY  FIAINTRP  MIALANG  MIAPROXY  MIAINTRP  AIALANG
# 0       NaN       NaN      NaN       NaN       NaN      NaN
# 1       NaN       NaN      NaN       NaN       NaN      NaN
# 2       NaN       NaN      NaN       NaN       NaN      NaN
#
# [3 rows x 219 columns]

# %%
df_vo2 = df[df['CVDESVO2'].notna() < 90]
df_vo2.head()
# Out:
#    SEQN  CVDEXSTS      CVDEXCMT  CVDEXCL1  CVDEXCL2  CVDEXCL3  CVDEXCL4  \
# 0   5.0       1.0  5.397605e-79       NaN       NaN       NaN       NaN
# 1   6.0       1.0  5.000000e+00       NaN       NaN       NaN       NaN
# 2   8.0       2.0  7.000000e+00       NaN       NaN       NaN       NaN
# 3  10.0       3.0  1.000000e+00       1.0       2.0       2.0       2.0
# 4  11.0       1.0  5.397605e-79       NaN       NaN       NaN       NaN
#
#    CVDEXCL5  CVDEXCL6  CVQ220A  ...  SIALANG  SIAPROXY  SIAINTRP  FIALANG  \
# 0       NaN       NaN      NaN  ...      NaN       NaN       NaN      NaN
# 1       NaN       NaN      NaN  ...      NaN       NaN       NaN      NaN
# 2       NaN       NaN      2.0  ...      NaN       NaN       NaN      NaN
# 3       2.0       2.0      NaN  ...      NaN       NaN       NaN      NaN
# 4       NaN       NaN      NaN  ...      NaN       NaN       NaN      NaN
#
#    FIAPROXY  FIAINTRP  MIALANG  MIAPROXY  MIAINTRP  AIALANG
# ...

# %%
men_df = df_vo2[df_vo2['RIAGENDR'] == 1]
fem_df = df_vo2[df_vo2['RIAGENDR'] == 2]

# %%
men_sub = men_df[men_df["CVDESVO2"] < 90]
# Out:
# <AxesSubplot: >

# %%
print(men_df['CVDESVO2'].mean())
print(men_sub['CVDESVO2'].mean())
# Out:
# 45.36688471352354
# 45.200546511627905

# %%
# VO2
fig = px.histogram(
    df_vo2, 
    x='CVDESVO2', 
    nbins=25,
    title="Histogram of VO2max",
    labels={
        "CVDESVO2": "Estimated VO2max (ml/kg/min)"
    },
    template="simple_white",
    color_discrete_map={
        "CVDESVO2": "red"
    }
)

line_placement = df_vo2['CVDESVO2'].mean()
fig.add_vline(
    type="line",
    line_color="salmon",
    line_width=4,
    opacity=1,
    line_dash="dot",
    x=line_placement
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 26
#      16 line_placement = df_vo2['CVDESVO2'].mean()
#      17 fig.add_vline(
#      18     type="line",
#      19     line_color="salmon",
#    (...)
#      23     x=line_placement
#      24 )
# ---> 26 fig.show()
#
# File ~/Documents/PersonalRepos/cwu-fitlab/fitlab-env/lib/python3.9/site-packages/plotly/basedatatypes.py:3398, in BaseFigure.show(self, *args, **kwargs)
#    3365 """
#    3366 Show a figure using either the default renderer(s) or the renderer(s)
#    3367 specified by the renderer argument
#    (...)
#    3394 None
#    3395 """
#    3396 import plotly.io as pio
# -> 3398 return pio.show(self, *args, **kwargs)
#
# File ~/Documents/PersonalRepos/cwu-fitlab/fitlab-env/lib/python3.9/site-packages/plotly/io/_renderers.py:396, in show(fig, renderer, validate, **kwargs)
# ...

# %%
# BF%
fig = px.histogram(
    df_vo2, 
    x='CVDESVO2', 
    nbins=25,
    title="Histogram of VO2max",
    labels={
        "CVDESVO2": "Estimated VO2max (ml/kg/min)"
    },
    template="simple_white",
    color_discrete_map={
        "CVDESVO2": "red"
    }
)

line_placement = df_vo2['CVDESVO2'].mean()
fig.add_vline(
    type="line",
    line_color="salmon",
    line_width=4,
    opacity=1,
    line_dash="dot",
    x=line_placement
)

fig.show()
